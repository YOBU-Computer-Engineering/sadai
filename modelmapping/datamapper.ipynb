// %%
function getJsonSync(filePath: string) {
    return JSON.parse(Deno.readTextFileSync(filePath));
}
var datas = getJsonSync("./data.json");

// %%
function removeQueryString(url) {
    // Check if the URL contains a "?"
    const index = url.indexOf("?");
    
    if (index !== -1) {
      // If "?" is found, remove the text after it
      return url.substring(0, index);
    }
    
    return url; // Return the original URL if no "?" is found
  }

// %%
function findYoutubeURL(arr) {
  const youtubeKeywordRegex = /youtube/i; 
    // Loop through the array
    if (!arr) return null; // Return null if the array is null
    for (let x = 0; x < arr.length; x++) {
      // Check if the current element is a URL and contains "youtube"
      if (typeof arr[x] === "string" && youtubeKeywordRegex.test(arr[x])) {
        return arr[x]; // Return the YouTube URL if found
      }
    }
    return null; // Return null if a YouTube URL is not found in the array
  }

// %%
function formatDate(date) {
  const day = String(date.getDate());
  const month = String(date.getMonth() + 1);
  const year = date.getFullYear();
  return `${day}.${month}.${year}`;
}

function generateDates(startDateStr, numberOfDays) {
  const dates = [];
  const startDate = new Date(startDateStr);

  // Check if the startDate is valid
  if (isNaN(startDate.getTime())) {
    console.error('Invalid start date');
    return dates;
  }

  // Generate dates day by day
  for (let i = 0; i < numberOfDays; i++) {
    const currentDate = new Date(startDate);
    currentDate.setDate(startDate.getDate() + i);

    // Format the date as dd.mm.yyyy using the formatDate function
    const formattedDate = formatDate(currentDate);
    dates.push(formattedDate);
  }

  return dates;
}

// %%
// {
//     _createdAt: "2022-11-04T15:02:12Z",
//     _id: "5124d837-f0be-49c4-b922-c879928376d0",
//     _rev: "pM6TnZHIqn4frJNABVdfAU",
//     _type: "tool",
//     _updatedAt: "2023-09-14T14:48:24Z",
//     dealText: "Use code FLIKI10FUTUREPEDIA to get 10% off on monthly plans",
//     defunct: { defunctReason: "No Longer Available", defunctStatus: false },
//     duplicate: false,
//     favCount: 3612,
//     id: "5124d837-f0be-49c4-b922-c879928376d0",
//     mainImage: {
//       _type: "image",
//       asset: {
//         _ref: "image-4dc642d29507d2e460bbcf47a815af9846729b70-1680x876-png",
//         _type: "reference"
//       }
//     },
//     newFeatures: ] "API" ],
//     pricing: ] "Freemium", "Deals" ],
//     publishedAt: "2022-11-04T15:02:12Z",
//     publishedAt_timestamp: 1667574132000,
//     reviewStats: { reviewCount: 7, reviewScore: 32 },
//     slug: { _type: "slug", current: "fliki" },
//     slugIndex: "fliki",
//     socialLinks: [
//       "mailto:support@fliki.ai",
//       "https://twitter.com/fliki_ai",
//       "https://facebook.com/flikiai",
//       "https://linkedin.com/company/fliki",
//       "https://instagram.com/fliki",
//       "https://www.youtube.com/channel/UCvYIu_hanlO9KeuiTsAryCA/videos"
//     ],
//     sponsorOfTheDay: false,
//     startingPrice: "8/mo",
//     status: "Published",
//     tagsIndex: ] "audio-editing", "text-to-speech", "video-generator" ],
//     toolCategories: [
//       {
//         _createdAt: "2023-01-01T18:45:47Z",
//         _id: "B8o7xf7Q4mKeMEiyAO326s",
//         _rev: "QG8TJXnGU8cT35HbKA3m72",
//         _type: "toolCategory",
//         _updatedAt: "2023-04-04T21:24:36Z",
//         categoryCode: "audio-3",
//         categoryName: "audio editing",
//         relatedCategories: [
//           {
//             _key: "26981a9280ea",
//             _ref: "UnZ2THkIAtRzfNq86WfnJi",
//             _type: "reference"
//           },
//           {
//             _key: "anpfFkxk4rKZ3eey56xLid",
//             _ref: "UnZ2THkIAtRzfNq86WfrII",
//             _type: "reference"
//           },
//           {
//             _key: "tEHtjdMQgv8vk3Xjstydfo",
//             _ref: "kxHCIyVPfR3nkfRNFsIaWC",
//             _type: "reference"
//           }
//         ],
//         slug: { _type: "slug", current: "audio-editing" }
//       },
//       {
//         _createdAt: "2023-01-01T18:45:44Z",
//         _id: "UnZ2THkIAtRzfNq86WfnJi",
//         _rev: "mYmyd4A1HQWMntvvgCUKTy",
//         _type: "toolCategory",
//         _updatedAt: "2023-04-04T21:27:50Z",
//         categoryCode: "audio-1",
//         categoryName: "text to speech",
//         relatedCategories: [
//           {
//             _key: "ekFFmMhZK1b4AZEmnoHYEW",
//             _ref: "UnZ2THkIAtRzfNq86WfoKc",
//             _type: "reference"
//           },
//           {
//             _key: "2fk7VMa2nGUEFdLqnhMtyP",
//             _ref: "kxHCIyVPfR3nkfRNFsIbbw",
//             _type: "reference"
//           }
//         ],
//         slug: { _type: "slug", current: "text-to-speech" }
//       },
//       {
//         _createdAt: "2023-01-01T18:45:50Z",
//         _id: "kxHCIyVPfR3nkfRNFsIbbw",
//         _rev: "26R050smgf4yGSgx8xdtOt",
//         _type: "toolCategory",
//         _updatedAt: "2023-04-04T21:32:53Z",
//         categoryCode: "video-1",
//         categoryName: "video generator",
//         relatedCategories: [
//           {
//             _key: "pbVx23Uct8BFJWoTGLUb4q",
//             _ref: "UnZ2THkIAtRzfNq86WfrII",
//             _type: "reference"
//           },
//           {
//             _key: "b4woo4NyLzk7WLJRGAmg8H",
//             _ref: "kxHCIyVPfR3nkfRNFsId7U",
//             _type: "reference"
//           },
//           {
//             _key: "3rhwNLcWJNPdENVJS6gYgS",
//             _ref: "kxHCIyVPfR3nkfRNFsIHgS",
//             _type: "reference"
//           }
//         ],
//         slug: { _type: "slug", current: "video-generator" }
//       }
//     ],
//     toolName: "Fliki",
//     toolShortDescription: "Create videos from blog posts in 2 mins",
//     verified: true,
//     verifiedReason: "Recommended",
//     websiteUrl: "https://fliki.ai/?via=futurepedia"
//   }


let mappedAr = datas.map((item, i) => {
    if (findYoutubeURL(item.socialLinks)) {
        return {
            "id": item.id,
            "date": generatedDates[i],
            "aiName": item.toolName,
            "aiWebsite": removeQueryString(item.websiteUrl),
            "description": item.toolShortDescription,
            "imagePath": item.mainImage.asset._ref,
            "videoIframeAdress": findYoutubeURL(item.socialLinks),
        };    
    }
}).filter(item=>item!=undefined);

// %%
mappedAr.splice(0,100);
// Out:
// []

// %%
let todayDate = new Date("12.1.2023")

const generatedDates = generateDates(todayDate, datas.length)

// %%
generatedDates
// Out:
// [
//   "1.12.2023",  "2.12.2023",  "3.12.2023",  "4.12.2023",  "5.12.2023",
//   "6.12.2023",  "7.12.2023",  "8.12.2023",  "9.12.2023",  "10.12.2023",
//   "11.12.2023", "12.12.2023", "13.12.2023", "14.12.2023", "15.12.2023",
//   "16.12.2023", "17.12.2023", "18.12.2023", "19.12.2023", "20.12.2023",
//   "21.12.2023", "22.12.2023", "23.12.2023", "24.12.2023", "25.12.2023",
//   "26.12.2023", "27.12.2023", "28.12.2023", "29.12.2023", "30.12.2023",
//   "31.12.2023", "1.1.2024",   "2.1.2024",   "3.1.2024",   "4.1.2024",
//   "5.1.2024",   "6.1.2024",   "7.1.2024",   "8.1.2024",   "9.1.2024",
//   "10.1.2024",  "11.1.2024",  "12.1.2024",  "13.1.2024",  "14.1.2024",
//   "15.1.2024",  "16.1.2024",  "17.1.2024",  "18.1.2024",  "19.1.2024",
//   "20.1.2024",  "21.1.2024",  "22.1.2024",  "23.1.2024",  "24.1.2024",
//   "25.1.2024",  "26.1.2024",  "27.1.2024",  "28.1.2024",  "29.1.2024",
//   "30.1.2024",  "31.1.2024",  "1.2.2024",   "2.2.2024",   "3.2.2024",
// ...

// %%
[

    { 
  
      id: ["5124d837-f0be-49c4-b922-c879928376d0"],
  
      date: ["1.12.2023"],
  
      aiName: ["Fliki"],
  
      aiWebsite: ["https://fliki.ai/"],
  
      description: ["Create videos from blog posts in 2 mins"],
  
      imagePath: ["image-4dc642d29507d2e460bbcf47a815af9846729b70-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCvYIu_hanlO9KeuiTsAryCA/videos"] 
  
    ],
  
    { 
  
      id: ["9d0612e3-1772-465b-bcf4-55a41e3d15cf"],
  
      date: ["2.12.2023"],
  
      aiName: ["Predict AI"],
  
      aiWebsite: ["https://www.neuronsinc.com/predict"],
  
      description: ["Predicts customer responses on creative assets"],
  
      imagePath: ["image-b283738f1c809cc2473e62b980b3644e21be143b-1200x700-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCiyRxJikaIqGHW3BWMB2lPQ"] 
  
    ],
  
    { 
  
      id: ["eea06e80-1e11-4cd8-bc0b-55656768689a"],
  
      date: ["12.12.2023"],
  
      aiName: ["tldv"],
  
      aiWebsite: ["https://tldv.io/"],
  
      description: ["The meeting recorder that transcribes & summarizes your calls with customer],prospect],and your te"[... 4 more character],
  
      imagePath: ["image-58dcb528088603aabd126489b5a6c8362cf2f498-1920x873-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCFuV24VqM-vydIw1bU4R_9Q"] 
  
    ],
  
    { 
  
      id: ["nCZqvxq1PbHe8K3wCm1ikM"],
  
      date: ["14.12.2023"],
  
      aiName: ["Adcreative.ai"],
  
      aiWebsite: ["https://free-trial.adcreative.ai/futurepedia"],
  
      description: ["Create conversion-focused ads & posts quickly & easily for better results."],
  
      imagePath: ["image-f4dfd7dc734935e005e6e7cc8e884c99af99cd74-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/c/AdCreativeAI"] 
  
    ],
  
    { 
  
      id: ["acaf15ac-9fda-45c2-8a14-d17a8a585f83"],
  
      date: ["18.12.2023"],
  
      aiName: ["Wondershare VirtuLook"],
  
      aiWebsite: ["https://virtulook.wondershare.com/"],
  
      description: ["Designed to enhance product visuals by seamlessly fitting products into saleable backgrounds."],
  
      imagePath: ["image-3fca199bc1b9611e155cff7e7f4e24c89d0f5531-2536x1258-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/user/Wondershare"] 
  
    ],
  
    { 
  
      id: ["7d33030c-2315-45ff-8cc6-7d68c79efe38"],
  
      date: ["25.12.2023"],
  
      aiName: ["Magical"],
  
      aiWebsite: ["https://magical.so/"],
  
      description: ["Magical AI - Welcome to the future of calendaring."],
  
      imagePath: ["image-30f31232304991e1725d551337a501ec7736c51b-1802x1241-png"],
  
      videoIframeAdress: ["https://www.youtube.com/c/Magicalteam"] 
  
    ],
  
    { 
  
      id: ["36e1add4-5ee6-49b6-9b44-6830ca64cf10"],
  
      date: ["26.12.2023"],
  
      aiName: ["Gizzmo AI"],
  
      aiWebsite: ["https://gizzmo.ai/"],
  
      description: ["Gizzmo WP plugin creates Amazon affiliate articles in just two clicks."],
  
      imagePath: ["image-c640caa2dfdc9fe86469833ee015f3075108bd76-1837x1106-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@gizzmo1330"] 
  
    ],
  
    { 
  
      id: ["00b87380-f0dd-4f3a-a2ec-6f3b412e9234"],
  
      date: ["28.12.2023"],
  
      aiName: ["Teal Resume Builder"],
  
      aiWebsite: ["https://www.tealhq.com/tools/resume-builder"],
  
      description: ["Resume Builder with built-in templates and guidance"],
  
      imagePath: ["image-28d62ac3d965c1b0773a5653f579f26b86604932-2538x1261-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/c/Tealhq/featured"] 
  
    ],
  
    { 
  
      id: ["28bbd2b8-0285-4d1d-b017-77d04dd00536"],
  
      date: ["15.1.2024"],
  
      aiName: ["STORYD"],
  
      aiWebsite: ["https://www.storyd.ai/"],
  
      description: ["A tool for data presentations"],
  
      imagePath: ["image-981a3cd0beae3db5d9281931c5d79b81ab5cfce3-3300x1856-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@storyd_ai"] 
  
    ],
  
    { 
  
      id: ["c0e13a3d-787f-4240-9ae1-83d8c7a7d222"],
  
      date: ["18.1.2024"],
  
      aiName: ["AssemblyAI"],
  
      aiWebsite: ["https://assemblyai.com/"],
  
      description: ["Transcribe and understand audio with AI models: AS],NL],Speech-to-Text."],
  
      imagePath: ["image-871a2f984ab0f03ae98b31dcde771225e29b9252-1920x1080-png"],
  
      videoIframeAdress: ["https://www.youtube.com/c/assemblyai"] 
  
    ],
  
    { 
  
      id: ["70e42cc8-a3af-483b-8d96-2b4a82d8952a"],
  
      date: ["19.1.2024"],
  
      aiName: ["Loopin AI"],
  
      aiWebsite: ["https://www.loopinhq.com/"],
  
      description: ["Turn your meetings into workspaces where your whole team can collaborate and access talking point],"[... 36 more character],
  
      imagePath: ["image-576f56f7164ece1224d10271875419a929cb49a8-1200x800-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCxhEAg4TR7g8z6R1gZ5af7A"] 
  
    ],
  
    { 
  
      id: ["a16a764c-93b7-4eab-ac9f-74fc027d77c3"],
  
      date: ["20.1.2024"],
  
      aiName: ["BrandBastion Lite"],
  
      aiWebsite: ["https://www.brandbastion.com/lite"],
  
      description: ["Easily monitor and manage all your social media conversations"],
  
      imagePath: ["image-b13dfc513f8aee5d5c77517dbb57b6ab56647ffe-1265x657-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC4S6kQRzRqBOAR6BVV7BR5w"] 
  
    ],
  
    { 
  
      id: ["f15e892c-3074-4a0f-8c3a-8aaebec26d82"],
  
      date: ["25.1.2024"],
  
      aiName: ["FineShare FineCam"],
  
      aiWebsite: ["https://www.fineshare.com/finecam/"],
  
      description: ["Transform your video calls and recordings with FineShare FineCam's advanced capabilities"],
  
      imagePath: ["image-a703aa7105f60824de93f48abb44107a3cb5f296-1680x876-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC9IYcIBGwv2G7aVONsV30mw"] 
  
    ],
  
    { 
  
      id: ["e6bd0ab7-ffcb-4f7d-b97e-63e27c4e9860"],
  
      date: ["27.1.2024"],
  
      aiName: ["Contents"],
  
      aiWebsite: ["https://contents.com/"],
  
      description: ["Contents is the Generative AI platform to create impactful content built for performance"],
  
      imagePath: ["image-1b007f933bb7f74dacdfa2ccf28b786a02474051-2539x1268-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC_H9EJ223LtXWG7RoaHaRWw"] 
  
    ],
  
    { 
  
      id: ["96dc431c-02bf-48c6-8f0b-0dfc91099882"],
  
      date: ["29.1.2024"],
  
      aiName: ["Eightify"],
  
      aiWebsite: ["https://www.eightify.app/"],
  
      description: ["Summaries for YT: 8 key ideas to decide if video is worth watching."],
  
      imagePath: ["image-168329f7fdeb93fad20d43661224a017853df7e8-1497x860-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=30F1nIF1-v8"] 
  
    ],
  
    { 
  
      id: ["76fe980a-dc80-43d7-913f-f07007c32bbc"],
  
      date: ["1.2.2024"],
  
      aiName: ["Chatfuel AI"],
  
      aiWebsite: ["https://chatfuel.com/ai"],
  
      description: ["AI-powered chatbot platform: elevate customer support and sales"],
  
      imagePath: ["image-07fa3b4c9611ad130d09531ae21b84f9af0fefe0-1680x920-png"],
  
      videoIframeAdress: ["https://www.youtube.com/chatfuel"] 
  
    ],
  
    { 
  
      id: ["61a17df6-d32f-42f0-b15a-7e3f00588c4f"],
  
      date: ["6.2.2024"],
  
      aiName: ["Jasper"],
  
      aiWebsite: ["https://jasper.ai"],
  
      description: ["Create content 10x faster with AI-powered copywriting tool"],
  
      imagePath: ["image-cfd9366784a7fda98637b46b46d03631667a0839-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/c/Jarvisai?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["649307d1-6e26-4eb8-8b64-ccf64a89c2be"],
  
      date: ["22.2.2024"],
  
      aiName: ["Descript"],
  
      aiWebsite: ["https://www.descript.com"],
  
      description: ["Create a text-to-speech model of your voice; try a live demo."],
  
      imagePath: ["image-a97f42c40eba97dd27dd2ade73bf198a92cf990b-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCg_u9QlUisVk89RizEpEvFA"] 
  
    ],
  
    { 
  
      id: ["76291196-da25-4a45-a1f2-4095a55eb2bd"],
  
      date: ["25.2.2024"],
  
      aiName: ["Synthesia"],
  
      aiWebsite: ["https://www.synthesia.io/"],
  
      description: ["Create AI videos from text. Eas],chea],scalable. Human presenters. Free demo."],
  
      imagePath: ["image-d7cbfc8f4ba1e34bf1acb49bd8aa47bc9901eaa8-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC0Rqs6pyPoGaMT5HFMFdslg"] 
  
    ],
  
    { 
  
      id: ["f73d7447-f89d-4c3a-93b0-d89def2d8d51"],
  
      date: ["27.2.2024"],
  
      aiName: ["Yaara"],
  
      aiWebsite: ["https://yaara.ai/"],
  
      description: ["Generate creative content from a given prompt"],
  
      imagePath: ["image-c44cc25cc3eb4dc6b4c1a1f43d853e98c8f20704-1920x977-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@yaara_ai?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["18a23c1e-9636-45f0-98b9-e5d9752b3cba"],
  
      date: ["5.3.2024"],
  
      aiName: ["Writesonic"],
  
      aiWebsite: ["https://writesonic.com/chat"],
  
      description: ["Create SEO-friendly content with AI for blog],website],and articles."],
  
      imagePath: ["image-be837214bd8c2249f9c5ba8e9bb5c7c9cc158bf4-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=xsVTqzratPs"] 
  
    ],
  
    { 
  
      id: ["71c14f70-6907-422c-8bc6-0bf0cf296116"],
  
      date: ["6.3.2024"],
  
      aiName: ["Easy-Peasy.AI"],
  
      aiWebsite: ["https://easy-peasy.ai/"],
  
      description: ["AI copywriting tools to help you tell your story in the most engaging way."],
  
      imagePath: ["image-27cd9553c6ce19c7d2f8998d27bced3a793983c2-1890x944-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@easy-peasy-ai"] 
  
    ],
  
    { 
  
      id: ["8f795131-2b62-477f-b6f2-402a8797e050"],
  
      date: ["12.3.2024"],
  
      aiName: ["Papercup"],
  
      aiWebsite: ["https://www.papercup.com/"],
  
      description: ["Automate dubbing with AI in multiple languages"],
  
      imagePath: ["image-8d872bc148b698554f72d38bc3c2f7e4f0098217-1757x883-jpg"],
  
      videoIframeAdress: ["https://www.papercup.com/industries/youtube-translation-content-creators"] 
  
    ],
  
    { 
  
      id: ["7821e3db-3b4e-4355-9d58-7b529e0e4dc6"],
  
      date: ["13.3.2024"],
  
      aiName: ["LongShot"],
  
      aiWebsite: ["https://longShot.ai"],
  
      description: ["AI writing assistant for creating SEO-friendly blogs."],
  
      imagePath: ["image-3efcea049728460777fb9b1bd178ebff38de0b28-1665x945-webp"],
  
      videoIframeAdress: ["https://www.youtube.com/c/longshotai?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["5e9d5cfe-74f9-4f30-bebd-af030259661e"],
  
      date: ["17.3.2024"],
  
      aiName: ["Taskade"],
  
      aiWebsite: ["https://www.taskade.com/"],
  
      description: ["Build a Second Brain for Your Team."],
  
      imagePath: ["image-786c182b4fa48436feaa916a2b8ab54723761272-1680x876-png"],
  
      videoIframeAdress: ["https://youtube.com/taskade"] 
  
    ],
  
    { 
  
      id: ["4431eac0-2a8a-421c-bf95-3d3a47365f18"],
  
      date: ["21.3.2024"],
  
      aiName: ["SheetAI.app"],
  
      aiWebsite: ["https://sheetai.app/"],
  
      description: ["AI-powered tool to quickly generate formulas for Google Sheets."],
  
      imagePath: ["image-e1267955992d7579abcf3ceb21dc79df3349e613-1870x957-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@sheetai?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["4a71d0d8-f26c-4ef5-a408-117356bd7e9d"],
  
      date: ["22.3.2024"],
  
      aiName: ["Airops"],
  
      aiWebsite: ["https://www.airops.com/"],
  
      description: ["Task-specific AI Apps that go beyond Chat-GPT—run NL],generate-data-informed conten],draft/fix/opt"[... 27 more character],
  
      imagePath: ["image-3bb4e916031f51bde43c3411ba2c4ec1a17bf8b4-1920x879-png"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=SW2Zj3Xktv4"] 
  
    ],
  
    { 
  
      id: ["eaf6bfce-010f-460c-833b-5e393e4bb4cb"],
  
      date: ["24.3.2024"],
  
      aiName: ["Wondershare Presentory"],
  
      aiWebsite: ["https://presentory.wondershare.com/"],
  
      description: ["AI-Powered PPT outline Generator that revolutionizes presentation],making them smarter and connecti"[... 11 more character],
  
      imagePath: ["image-85e83827765196eeb4954e282dbd91fe80fc5ddc-2532x1243-png"],
  
      videoIframeAdress: ["https://www.youtube.com/user/Wondershare"] 
  
    ],
  
    { 
  
      id: ["1fc1d3b7-a1fb-4a36-8174-3cbfceb4b428"],
  
      date: ["1.4.2024"],
  
      aiName: ["DrugCard"],
  
      aiWebsite: ["https://drug-card.io/"],
  
      description: ["AI-Enabled Local Literature Screening for Pharmaceuticals"],
  
      imagePath: ["image-7bbf49e4c0b2e05ac813cc10d6ac65eddc8425c0-2520x1252-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCufbHwOccg8-uUT7FS5toIw"] 
  
    ],
  
    { 
  
      id: ["a50338e4-e54d-4404-ba7f-52fc7f86bdfc"],
  
      date: ["3.4.2024"],
  
      aiName: ["ReDoc"],
  
      aiWebsite: ["https://redoc.live/"],
  
      description: ["ReDoc is your ultimate writing assistan],here to transform your writing process."],
  
      imagePath: ["image-fb0ed68c2e00d712f04a43bb9f1750a80aee571b-2526x1256-jpg"],
  
      videoIframeAdress: ["https://youtube.com/@redoc-ai"] 
  
    ],
  
    { 
  
      id: ["0aeda60f-4b9f-4df6-b6a4-3640ca8b89bd"],
  
      date: ["5.4.2024"],
  
      aiName: ["HubSpot AI"],
  
      aiWebsite: ["https://www.hubspot.com/products/artificial-intelligence"],
  
      description: ["Supercharge Your Work With HubSpot AI."],
  
      imagePath: ["image-3b2df2a94981b0cf3ede251ea0550a38f09fb89d-1918x1182-jpg"],
  
      videoIframeAdress: ["https://youtube.com/user/HubSpot"] 
  
    ],
  
    { 
  
      id: ["cda379e2-fc61-4790-a399-ee720286b9d1"],
  
      date: ["10.4.2024"],
  
      aiName: ["Contify News API"],
  
      aiWebsite: ["https://www.contify.com/news-feed-api/"],
  
      description: ["Clean and granula],business-specific updates delivered through REST API and Webhooks"],
  
      imagePath: ["image-4e61a1a975891642c260934b207bda92c64d8e5e-2533x1261-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/c/contifynewdelhi"] 
  
    ],
  
    { 
  
      id: ["969a15fd-22a1-465a-9527-5999165f6ed8"],
  
      date: ["18.4.2024"],
  
      aiName: ["Pdfpals"],
  
      aiWebsite: ["https://pdfpals.com/"],
  
      description: ["Native PDF Interaction App for macOS"],
  
      imagePath: ["image-98a2e9b04ce214f6b2c1ec6ef5002efad97f117a-2525x1256-jpg"],
  
      videoIframeAdress: ["https://youtube.com/@pdfpals"] 
  
    ],
  
    { 
  
      id: ["dd139a07-28b2-4220-86e3-17e05239f942"],
  
      date: ["19.4.2024"],
  
      aiName: ["Spikes Studio"],
  
      aiWebsite: ["https://spikes.studio/"],
  
      description: ["Video editing tool designed to transform lengthy videos into viral clips."],
  
      imagePath: ["image-516f5ada74661dcd4f39ac2643abd8623911be99-2539x1244-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@SpikesStudio"] 
  
    ],
  
    { 
  
      id: ["b505f1cc-7382-46c8-a4d6-43da09c291d3"],
  
      date: ["5.5.2024"],
  
      aiName: ["SiteSpeakAI"],
  
      aiWebsite: ["https://sitespeak.ai/"],
  
      description: ["Provide real-time responses to customer inquiries about products and service],operating 24/7 to enh"[... 49 more character],
  
      imagePath: ["image-1d1c42b0616e2c029d88ac6d4bd79b2cd86bff61-2538x1257-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@sitespeakai"] 
  
    ],
  
    { 
  
      id: ["de655493-a176-41bf-85ec-b6fbf0f1b98c"],
  
      date: ["12.5.2024"],
  
      aiName: ["HappyChat AI"],
  
      aiWebsite: ["https://www.happychat.ai/"],
  
      description: ["Instantly implement AI-powered chatbots for better customer engagement."],
  
      imagePath: ["image-1f770812de6f83a3eb30e7d158e55b998e00cfaf-2523x1262-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@happychat_ai"] 
  
    ],
  
    { 
  
      id: ["449f02d8-c318-4e1b-a00c-cac955e3c3dd"],
  
      date: ["18.5.2024"],
  
      aiName: ["Threado"],
  
      aiWebsite: ["https://threado.com/ai"],
  
      description: ["Empower Your Business with Threado - Where Automation Meets Growt],Leaving You Free to Unwind!"],
  
      imagePath: ["image-dc8aa5460bf399ec6ccd47d7714172ecc6b8c3eb-2533x1256-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCs4C3dCa3GeeSMiPdE3Kwyw"] 
  
    ],
  
    { 
  
      id: ["7f0523fe-19d9-4f36-b1a8-2d3fcd4f85ba"],
  
      date: ["19.5.2024"],
  
      aiName: ["Yepp AI"],
  
      aiWebsite: ["https://www.yepp.ai/"],
  
      description: ["Your Ultimate Solution for Transforming Data into Exceptional Content!"],
  
      imagePath: ["image-d8b5ecd418fcedd233cbda28237313c0ba281d86-2533x1239-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC1HTRDibKGtHGs_JkMGcjZg"] 
  
    ],
  
    { 
  
      id: ["874361a2-645a-4bf8-9b28-3ddb932498e4"],
  
      date: ["1.6.2024"],
  
      aiName: ["Beatopia"],
  
      aiWebsite: ["https://www.beatopia.com/ai-lyrics-generator"],
  
      description: ["Empowers musicians to create better songs using AI-generated lyrics and exclusive beats crafted by G"[... 24 more character],
  
      imagePath: ["image-ca14f76d5de5244851e30cb0a60f9bcafd498a1b-1897x916-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC_vuNweNng-eDsaHcCTCNwg"] 
  
    ],
  
    { 
  
      id: ["96a2751d-73b0-47b6-84f2-424dd1f598c1"],
  
      date: ["7.6.2024"],
  
      aiName: ["CM3leon by Meta"],
  
      aiWebsite: ["https://ai.meta.com/blog/generative-ai-text-images-cm3leon"],
  
      description: ["CM3leon is a state-of-the-art generative model that excels in both text-to-image and image-to-text g"[... 10 more character],
  
      imagePath: ["image-dafc86501f348df4436c889ed2c44887f97b9187-1897x918-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@FacebookAI"] 
  
    ],
  
    { 
  
      id: ["1b00e1ba-86b9-478c-b0a5-f5b40541b830"],
  
      date: ["8.6.2024"],
  
      aiName: ["Scout.Asserter.AI"],
  
      aiWebsite: ["https://scout.asseter.ai/"],
  
      description: ["Introducing Scout by Asseter.ai: Unveiling a New Era in 3D Asset Discovery"],
  
      imagePath: ["image-f18f066e89e07c0202d67448b2265cf0faff8a8c-1920x913-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCvoujjptCeCL0r_P9CDk8yw"] 
  
    ],
  
    { 
  
      id: ["96d49679-3b98-4fa7-8ce7-c6c0822e5d75"],
  
      date: ["13.6.2024"],
  
      aiName: ["Storyboard Hero"],
  
      aiWebsite: ["https://storyboardhero.ai/"],
  
      description: ["Designed to quickly and cost-effectively generate video concepts and storyboards"],
  
      imagePath: ["image-a7a8501912ae27e7d2dce5731ba117e8a8187f10-1920x921-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@StoryboardHero"] 
  
    ],
  
    { 
  
      id: ["0fb0dc77-db29-4cc8-952d-2a9d99cee802"],
  
      date: ["18.6.2024"],
  
      aiName: ["Forms.app"],
  
      aiWebsite: ["https://forms.app/"],
  
      description: ["Forms.app: Create Web Form],Survey],and Quizzes with Ease"],
  
      imagePath: ["image-bb91a75505faa98deb6db64601595d1c30bcdb55-1897x920-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCQt7DCyRWr9190OhYKbeZzA"] 
  
    ],
  
    { 
  
      id: ["8b713bab-90b3-426a-b3f9-325b76410adf"],
  
      date: ["29.6.2024"],
  
      aiName: ["Azameo"],
  
      aiWebsite: ["https://azameo.com/"],
  
      description: ["Azameo is an all-in-one platform powered by AI that helps optimize online Ads for skyrocketing onlin"[... 7 more character],
  
      imagePath: ["image-3850d7623792965f88a9b87fc927943f1d92259f-2532x1270-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCNIhz6duk8huUwcM6R1O7dA"] 
  
    ],
  
    { 
  
      id: ["853ae72b-61ac-4043-a869-c193a83ef3bc"],
  
      date: ["1.7.2024"],
  
      aiName: ["Alpha3D"],
  
      aiWebsite: ["https://www.alpha3d.io/"],
  
      description: ["Alpha3D is a revolutionary generative AI-powered platform that transforms 2D images into high-qualit"[... 21 more character],
  
      imagePath: ["image-a4d8fe1e707bd3920a200e48fab3287f5fcd8000-2532x1269-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@alpha3dio"] 
  
    ],
  
    { 
  
      id: ["50bb29c9-2dd8-41ce-8138-50ae6015b04f"],
  
      date: ["7.7.2024"],
  
      aiName: ["Bubble"],
  
      aiWebsite: ["https://bubble.io/ai"],
  
      description: ["Bubble is a powerful tool that allows users to build AI-powered apps without the need for coding."],
  
      imagePath: ["image-410dad92405fcb802da96b3c4b5198d4931157ad-2535x1262-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/c/BubbleIO"] 
  
    ],
  
    { 
  
      id: ["16a604dc-a292-4a08-ab4a-baf0d9971f98"],
  
      date: ["8.7.2024"],
  
      aiName: ["dotBRAND"],
  
      aiWebsite: ["https://dotbrand.design/"],
  
      description: ["dotBRAND is an AI-powered tool designed to empower designers by helping them identify ideal clients "[... 43 more character],
  
      imagePath: ["image-d3eb75b2da55286de4aa5f5a4281baff5d3bb061-2533x1264-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@dotbrandsaas7092"] 
  
    ],
  
    { 
  
      id: ["4c4688ad-d937-457e-8614-4febe3d8d8e5"],
  
      date: ["23.7.2024"],
  
      aiName: ["Coursebox"],
  
      aiWebsite: ["https://www.coursebox.ai/"],
  
      description: ["Create an online course in under one hour with AI"],
  
      imagePath: ["image-30ccd84a4cbbc5690300e96945c463608edae280-2535x1266-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UChZ26y9B2waBHvY8c_uG0ow"] 
  
    ],
  
    { 
  
      id: ["b965eead-7777-4583-b1d9-af0651e1afd8"],
  
      date: ["28.7.2024"],
  
      aiName: ["Parseur"],
  
      aiWebsite: ["https://parseur.com/"],
  
      description: ["Parseur is a powerful data entry software that automates text extraction from email],PDF],and othe"[... 69 more character],
  
      imagePath: ["image-c20f73d795d70378c22ecb429755d72481f1893d-2537x1247-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@parseur"] 
  
    ],
  
    { 
  
      id: ["05754d93-3ea1-46f2-83d4-6db64a3d5198"],
  
      date: ["31.7.2024"],
  
      aiName: ["Final Touch"],
  
      aiWebsite: ["https://final-tou.ch/"],
  
      description: ["Professional photography and design power at your fingertips"],
  
      imagePath: ["image-5e45843181f107f6c1f5d96c06d4c640461f1ee2-2539x1278-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@FinalTouchai"] 
  
    ],
  
    { 
  
      id: ["9b2c039d-d948-4e1a-bc21-0465695eaacf"],
  
      date: ["13.8.2024"],
  
      aiName: ["WOXO - Idea to Videos"],
  
      aiWebsite: ["https://woxo.tech/idea-to-video"],
  
      description: ["AI-Generated videos in just a minute!"],
  
      imagePath: ["image-13125b186cf9a773a9bf061fdb896b0086071c69-2533x1266-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCUjYDLLKFfBbTbaiBSFT3_A"] 
  
    ],
  
    { 
  
      id: ["5de6bec2-06db-4371-a69b-ac60a804e420"],
  
      date: ["17.8.2024"],
  
      aiName: ["PromptInterface.ai"],
  
      aiWebsite: ["https://www.promptinterface.ai/"],
  
      description: ["Create Personalized AI Assistants with Prompt Engineering"],
  
      imagePath: ["image-1064f65afe998933281bf405984c97e41a4b369c-2533x1267-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCQ6bzU_fZInWsZ_iog8vG8w"] 
  
    ],
  
    { 
  
      id: ["639d9962-de0c-43c1-bfc1-5cfe702784dd"],
  
      date: ["27.8.2024"],
  
      aiName: ["Quick Creator"],
  
      aiWebsite: ["https://quickcreator.io/"],
  
      description: ["Transform your blog and landing pages with AI-powered Quick Creator"],
  
      imagePath: ["image-f6433b127dcd8b7aa0a1b48625b1ce0340f93f10-2530x1268-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@QuickCreator10"] 
  
    ],
  
    { 
  
      id: ["275a7a08-0dc9-4a44-8d43-3eab0494701f"],
  
      date: ["4.9.2024"],
  
      aiName: ["Writesparkle.ai"],
  
      aiWebsite: ["https://writesparkle.ai/"],
  
      description: ["Streamline your content creation process by seamlessly integrating Writesparkle with your favorite t"[... 19 more character],
  
      imagePath: ["image-3e17906a185ca8f696388b0bfa83aab2c6e4b3ce-2534x1269-jpg"],
  
      videoIframeAdress: ["https://youtube.com/@WriteSparkle"] 
  
    ],
  
    { 
  
      id: ["3d0ccb0e-4613-407b-964f-868a4480b36f"],
  
      date: ["1.10.2024"],
  
      aiName: ["FineShare FineVoice"],
  
      aiWebsite: ["https://www.fineshare.com/finevoice/"],
  
      description: ["Unleash the charm of your voice with AI"],
  
      imagePath: ["image-12e92f208dd6607122a0b29addc739e8527150fb-1680x876-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC9IYcIBGwv2G7aVONsV30mw"] 
  
    ],
  
    { 
  
      id: ["e18cf6e8-3f00-4685-93d6-61f7146dfd5e"],
  
      date: ["3.10.2024"],
  
      aiName: ["Opera One Browser"],
  
      aiWebsite: ["https://www.opera.com/one"],
  
      description: ["Opera One is a redesigned browse],currently in early-access developer versio],that offers a liquid"[... 82 more character],
  
      imagePath: ["image-8548502155526307dfbdcdacdcd665adf1547f59-2539x1273-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/opera"] 
  
    ],
  
    { 
  
      id: ["e40289cd-7721-445f-8c47-6d2070f50e5b"],
  
      date: ["7.10.2024"],
  
      aiName: ["SEOWriting AI"],
  
      aiWebsite: ["https://seowriting.ai"],
  
      description: ["Seowriting AI is a free AI writing tool designed to generate marketing copy that ranks well in Googl"[... 1 more characte],
  
      imagePath: ["image-3a6f730f48a06a6f4cc9fdc64630d44f1397f510-2536x1272-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC0tfX7oaQxfV_HDwJRHRfHw"] 
  
    ],
  
    { 
  
      id: ["7beaa9de-86a3-48d2-97c8-c97081c510ec"],
  
      date: ["8.10.2024"],
  
      aiName: ["PowerDMARC"],
  
      aiWebsite: ["https://powerdmarc.com/"],
  
      description: ["DMARC Protection is a service that helps domain owners protect their email domains from unauthorized"[... 25 more character],
  
      imagePath: ["image-13672e35381a3dbc73c8f2702f6306dcf40fb0f8-2541x1215-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCf9Kl3IHMACxXCppaaJOe2Q"] 
  
    ],
  
    { 
  
      id: ["8c254440-3bf6-435a-b324-0e498c7a7de0"],
  
      date: ["9.10.2024"],
  
      aiName: ["Deepshot AI"],
  
      aiWebsite: ["https://www.deepshot.ai/"],
  
      description: ["Deepshot is a customizable dialogue generation and replacement software that revolutionizes video re"[... 19 more character],
  
      imagePath: ["image-7626402d07607c6a2f3227e27aa873cfc913998a-2537x1271-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=sEg5RMdysx4"] 
  
    ],
  
    { 
  
      id: ["82b61076-2b2b-444d-b530-359c56c235b9"],
  
      date: ["10.10.2024"],
  
      aiName: ["Insight7"],
  
      aiWebsite: ["https://insight7.io/"],
  
      description: ["Insight7 is an AI-powered tool that helps teams unlock customer insights and prioritize the right pr"[... 7 more character],
  
      imagePath: ["image-0f6bc99c0bd7c9e6e755a200544c6be8aeec2eb2-2528x1267-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCLeLvSNA_juj9sYDJc5tvdg"] 
  
    ],
  
    { 
  
      id: ["905939f7-cfe8-44af-98b3-44a61d1d1aae"],
  
      date: ["12.10.2024"],
  
      aiName: ["Stellaris AI"],
  
      aiWebsite: ["https://www.stellaris-ai.com/"],
  
      description: ["With Stellaris A],users can trust that their queries and conversations will be met with intelligent"[... 23 more character],
  
      imagePath: ["image-e2d291da2c5293858909d723aa363cca7bdea5e4-2534x1270-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@StellarisAI"] 
  
    ],
  
    { 
  
      id: ["d27adacf-18fb-4410-b98d-dc3c4f01bec6"],
  
      date: ["15.10.2024"],
  
      aiName: ["Giftmethat"],
  
      aiWebsite: ["https://www.giftmethat.io/"],
  
      description: ["Revolutionizing Gift-Giving : GiftMeThat's AI-Powered Platform"],
  
      imagePath: ["image-afa5f8a2dc1063a03628ef4bfba74db9e5e071bf-2523x1262-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCCfnJiQqfW5-vr7__PGfVKg"] 
  
    ],
  
    { 
  
      id: ["cf31e75a-1679-453b-8f22-0b362f2add3e"],
  
      date: ["16.10.2024"],
  
      aiName: ["DataDistillr"],
  
      aiWebsite: ["https://datadistillr.com/"],
  
      description: ["Integrating your data has never been easier."],
  
      imagePath: ["image-38e04d28afecf9d4076c65bd0a049aba05ac45b9-2544x1265-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC4bsXaNJ8BYt4bP2Ab02j4w/featured"] 
  
    ],
  
    { 
  
      id: ["46686f2f-9cd8-486f-8d0b-14523b7e4733"],
  
      date: ["19.10.2024"],
  
      aiName: ["Deepfake Generator"],
  
      aiWebsite: ["https://www.synthesia.io/tools/deepfake-video-maker"],
  
      description: ["Create professional videos with photo-realistic avatars using Deepfake Generator"],
  
      imagePath: ["image-d67c0e0ef3480b0066aa466b1f9f8a30ad374eb2-2426x1261-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC0Rqs6pyPoGaMT5HFMFdslg"] 
  
    ],
  
    { 
  
      id: ["e20d104d-bfb6-4737-bd65-f293cd6ad4d6"],
  
      date: ["31.10.2024"],
  
      aiName: ["Trickle AI: Prompts Warehouse"],
  
      aiWebsite: ["https://www.trickle.so/prompts-db"],
  
      description: ["Infuse the power of AI into your workflow and seamlessly integrate over 200 ready-to-use prompts int"[... 115 more character],
  
      imagePath: ["image-6356e65fff7b05f7e681f90588fd62df05ee22d0-1920x908-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCbPl2tS366RvUiWHQBrGinQ"] 
  
    ],
  
    { 
  
      id: ["f54fb7ed-04f4-472f-8f28-2df5b8bb1d77"],
  
      date: ["4.11.2024"],
  
      aiName: ["Yobi"],
  
      aiWebsite: ["https://yobi.app/"],
  
      description: ["Optimise Your Communication with Yobi's Central Platform"],
  
      imagePath: ["image-6f5a6d5e825eeea9a330090e036dedad6f6d3825-2535x1271-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC7EdWExNF4ZNnj_iobStrCg"] 
  
    ],
  
    { 
  
      id: ["3d0e4b55-eff7-40bd-9ff0-1abc203de34b"],
  
      date: ["6.11.2024"],
  
      aiName: ["MagicChat AI"],
  
      aiWebsite: ["https://www.magicchat.ai/"],
  
      description: ["Train a ChatGPT-like chatbot for your website"],
  
      imagePath: ["image-2dfe711b904a934f9806aab7b45c1119245c7c30-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@MagicChatAI?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["3416dd42-657b-4621-8472-2083028f8182"],
  
      date: ["10.11.2024"],
  
      aiName: ["ChatGPT Plugins"],
  
      aiWebsite: ["https://openai.com/blog/chatgpt-plugins"],
  
      description: ["ChatGPT Plugins to access real-world data with APIs"],
  
      imagePath: ["image-56a59c254e3f99106846d6d6ddcd412f653570f2-1915x895-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCBrAMWry4Z5GJlAmd-KdU2A"] 
  
    ],
  
    { 
  
      id: ["f6647b66-4c8e-4323-8d06-80dba748192c"],
  
      date: ["11.11.2024"],
  
      aiName: ["Keywords Everwhere"],
  
      aiWebsite: ["https://keywordseverywhere.com/"],
  
      description: ["Keyword Research and ChatGPT prompts browser extension"],
  
      imagePath: ["image-1f421d9f99a7b7eb50a6d724d5a0b0d9eaa1a12e-1920x805-png"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=UWtKgXhOigI"] 
  
    ],
  
    { 
  
      id: ["a94187e5-e4ff-4c34-984a-97a693eba912"],
  
      date: ["12.11.2024"],
  
      aiName: ["Zoom IQ"],
  
      aiWebsite: ["https://blog.zoom.us/zoom-iq-smart-companion/"],
  
      description: ["Capture meaningful and actionable insights from customer interactions "],
  
      imagePath: ["image-e9c4795740b9742a387f14dfb561c2935bdd1cb7-1350x1104-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@zoom"] 
  
    ],
  
    { 
  
      id: ["396b15f7-07bb-4aa6-9271-b2d3efd6d024"],
  
      date: ["11.12.2024"],
  
      aiName: ["Datature"],
  
      aiWebsite: ["https://datature.io"],
  
      description: ["Manage dataset],annotat],trai],and deploy"],
  
      imagePath: ["image-e02be6f1a67f76bc42940ce981ad17cfffe70da8-1820x941-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCd3UQZ9piasi0vgfg5xI59w"] 
  
    ],
  
    { 
  
      id: ["ae3d593c-04e6-488d-aa0b-48e4ef06efde"],
  
      date: ["12.12.2024"],
  
      aiName: ["One AI"],
  
      aiWebsite: ["https://www.oneai.com"],
  
      description: ["Generative AI API for businesses "],
  
      imagePath: ["image-1181b07d5ce1f4fae166c916bd83f63a9e8e33ab-1892x991-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC7Iq6Yfks57GTa-He72fsgw"] 
  
    ],
  
    { 
  
      id: ["f6ced49c-a249-4333-8f0a-8cb74163ad72"],
  
      date: ["15.12.2024"],
  
      aiName: ["Pencil"],
  
      aiWebsite: ["https://www.trypencil.com"],
  
      description: ["Create winning ads 10x faster with AI"],
  
      imagePath: ["image-80d82f67aee523d586b95d16c39413d29a6e4cd4-1900x996-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC-7RWSiJdbZua2BfFxq68fQ"] 
  
    ],
  
    { 
  
      id: ["7c288082-1ff1-43c9-9c71-8e551539daa1"],
  
      date: ["21.12.2024"],
  
      aiName: ["Cookup.ai"],
  
      aiWebsite: ["Https://cookup.ai"],
  
      description: ["AI apps for every usecase"],
  
      imagePath: ["image-a6f7e913f3484c407ec68c45fd5d4fb6f7f9dad4-1806x902-jpg"],
  
      videoIframeAdress: ["#youtube"] 
  
    ],
  
    { 
  
      id: ["808f6a23-c5b3-466b-bf23-d22f789590c2"],
  
      date: ["23.12.2024"],
  
      aiName: ["Mixo.io"],
  
      aiWebsite: ["https://mixo.io/"],
  
      description: ["Launch a startup in seconds with AI."],
  
      imagePath: ["image-d0ab67eddeb6954e27793024fdbd306d50c021b0-1774x899-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@mixoapp"] 
  
    ],
  
    { 
  
      id: ["76fa26c7-1ff1-4acc-a870-9bdc5bdf91e9"],
  
      date: ["28.12.2024"],
  
      aiName: ["Uberduck"],
  
      aiWebsite: ["https://uberduck.ai/"],
  
      description: ["Create voice-over audio and AI-generated raps with Uberduck."],
  
      imagePath: ["image-c753d974c7bf3ebf9902862879cba5a17a60e09f-1844x884-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCo07oTa8sdzjRzjk1K9_zgQ"] 
  
    ],
  
    { 
  
      id: ["c08bc78d-e883-44ba-8598-806fcf3b143c"],
  
      date: ["14.1.2025"],
  
      aiName: ["Yoodli AI"],
  
      aiWebsite: ["https://app.yoodli.ai/"],
  
      description: ["AI speech coach helps you improve your communication skills with feedback"],
  
      imagePath: ["image-4c0871d865b637a4b8483ce768b1c65c80285eb4-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC_mNbcKxBpRmCuyn1H57y0w"] 
  
    ],
  
    { 
  
      id: ["f3b2c872-154a-4879-816a-20430af4049a"],
  
      date: ["17.1.2025"],
  
      aiName: ["Facial Assessment Tool"],
  
      aiWebsite: ["https://qoves.com/facial-assessment-tool/"],
  
      description: ["Use ML to analyze your face and get cosmetic suggestions."],
  
      imagePath: ["image-50af08e6164071cc8a0226b7218dc43fdd9520a0-1120x841-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCnlvhYDQLq4d_C3JYEVnWAQ"] 
  
    ],
  
    { 
  
      id: ["8b912acd-b8e8-4249-8552-3a5dc071b25a"],
  
      date: ["24.1.2025"],
  
      aiName: ["Gooey.AI"],
  
      aiWebsite: ["https://gooey.ai"],
  
      description: ["Prototype how AI will integrate with your own site/app."],
  
      imagePath: ["image-4a51f1bddd6c487a33ecc61a2721da6dc23f2c09-1827x892-jpg"],
  
      videoIframeAdress: ["https://youtube.com/playlist?list=PL4aOhrbpcqyYGrLHMyZIgVNej2pa53uac"] 
  
    ],
  
    { 
  
      id: ["06b4d003-a2fa-4830-a37a-81bef976a915"],
  
      date: ["30.1.2025"],
  
      aiName: ["MeetGeek"],
  
      aiWebsite: ["https://meetgeek.grsm.io/h3c09ouw0l03"],
  
      description: ["Maximize the value of meetings by automatically recording and summarizing it"],
  
      imagePath: ["image-0adb4d1fdb5cf70f8cf82327c8f8e997fbdf1eec-1807x857-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCxZnYQwk7a1OFDL0DiNUBTg"] 
  
    ],
  
    { 
  
      id: ["9a23a8d0-d57c-45ad-b89a-c7cb61a9a15b"],
  
      date: ["16.2.2025"],
  
      aiName: ["VidIq"],
  
      aiWebsite: ["https://vidiq.com/futurepedia"],
  
      description: ["Find topics & keywords for Y],with personalized prompts & analytics."],
  
      imagePath: ["image-77459cc0963d126b22d2437ede9091a55a0617bd-1815x934-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/user/vidIQchannel/"] 
  
    ],
  
    { 
  
      id: ["b1d93bc4-e90b-49fd-8a47-3702de2e2dd7"],
  
      date: ["27.2.2025"],
  
      aiName: ["NeevaAI"],
  
      aiWebsite: ["https://neeva.com/"],
  
      description: ["AI-powered search with real-tim],accurate results and source info."],
  
      imagePath: ["image-26963cea8319c9878eaaa9bf121037957e75959a-1641x932-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCkcPF5bjGSK__hT379k_4og"] 
  
    ],
  
    { 
  
      id: ["f9258cbe-1754-4db0-a0d7-4fcc08a49ab3"],
  
      date: ["28.2.2025"],
  
      aiName: ["Tiledesk"],
  
      aiWebsite: ["https://tiledesk.com/"],
  
      description: ["Combine Chatbots & Live Chat for boosted RO],one inbox for all channels."],
  
      imagePath: ["image-91f93f824b8511651d1566649d3eac420a68cb08-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCv4EmbXGO90d9xF6wM1OvqA"] 
  
    ],
  
    { 
  
      id: ["8f8aaafe-f177-4559-888a-c3ccff488d52"],
  
      date: ["1.3.2025"],
  
      aiName: ["Krisp"],
  
      aiWebsite: ["https://krisp.ai/"],
  
      description: ["Krisp's AI removes background noise & echo from meetings"],
  
      imagePath: ["image-3e1260aee0769c695de989cea3c6237bddcb7f6f-2965x1491-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCAMZinJdR9P33fZUNpuxXtg/playlists"] 
  
    ],
  
    { 
  
      id: ["d1a5fcb0-fcc8-4696-8368-33692c24368f"],
  
      date: ["2.3.2025"],
  
      aiName: ["Amazon CodeWhisperer"],
  
      aiWebsite: ["https://aws.amazon.com/codewhisperer/"],
  
      description: ["Write code faster with ML-powered code recommendations."],
  
      imagePath: ["image-a4c87221bbd05cb78c662a25d733c745c225ca96-1821x948-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/user/AmazonWebServices/Cloud/"] 
  
    ],
  
    { 
  
      id: ["f6d308fc-9ed7-401b-a386-2603097b3385"],
  
      date: ["11.3.2025"],
  
      aiName: ["Validator AI"],
  
      aiWebsite: ["https://www.validatorai.com/"],
  
      description: ["Get feedback to validate & improve startup ideas"],
  
      imagePath: ["image-b1b42662178203190ec7adca78d2da0bf19cdb91-1863x793-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCWlmPaoLVPQPT2xsAWfn3gg?sub_confirmation=1"] 
  
    ],
  
    { 
  
      id: ["efc14214-ce96-4647-87c1-e375265a5870"],
  
      date: ["12.3.2025"],
  
      aiName: ["Tabnine"],
  
      aiWebsite: ["https://www.tabnine.com/"],
  
      description: ["Tabnine helps developers write code faste],in any IDE."],
  
      imagePath: ["image-93db1ad4a6019078f336f202d3814e1c15a55218-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UC3ZLFXRRmK3XbT5Oq0qPLqA"] 
  
    ],
  
    { 
  
      id: ["efae8c38-1e46-4f3f-82da-f367ec25a1bc"],
  
      date: ["13.3.2025"],
  
      aiName: ["Glasp"],
  
      aiWebsite: ["https://glasp.co/ai-writing"],
  
      description: ["Highlight & organize web quotes and access like-minded people's learning"],
  
      imagePath: ["image-8398fe18d54ef608c9b796a35a2b576d2d9e6128-1700x848-jpg"],
  
      videoIframeAdress: ["https://www.producthunt.com/posts/youtube-highlighter-by-glasp?utm_source=badge-featured&utm_medium="[... 50 more characters 
  
    ],
  
    { 
  
      id: ["da209f54-5be4-40b2-a833-bc03333e3ef2"],
  
      date: ["18.3.2025"],
  
      aiName: ["Cheat Layer"],
  
      aiWebsite: ["https://cheatlayer.com/"],
  
      description: ["No-code automation with ML to solve complex business problems"],
  
      imagePath: ["image-1623cbdbeb1624a6819ccd65faf53564d62b4e7e-2530x1274-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/cheatlayer"] 
  
    ],
  
    { 
  
      id: ["c1f4e4a5-86ce-4fb4-ad4c-0be8758fe0de"],
  
      date: ["24.3.2025"],
  
      aiName: ["Copilot"],
  
      aiWebsite: ["https://github.com/features/copilot"],
  
      description: ["AI pair programmer that suggests code & functions in real-time from your editor."],
  
      imagePath: ["image-c43d5d7960323bc2ce331ac9cbe962fca8783cd7-1920x1080-png"],
  
      videoIframeAdress: ["https://www.youtube.com/github"] 
  
    ],
  
    { 
  
      id: ["b69c5f7f-9aea-4bc6-9424-964c8e330ba6"],
  
      date: ["26.3.2025"],
  
      aiName: ["Palette.fm"],
  
      aiWebsite: ["https://palette.fm/"],
  
      description: ["Colorize B&W pics automatically"],
  
      imagePath: ["image-1667d98352c37ae7d207a2e6fe99811f2845a535-1811x888-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/watch?v=xKPk7tG2upc"] 
  
    ],
  
    { 
  
      id: ["92e89cca-54c2-48fa-88a8-bd907f2e99be"],
  
      date: ["3.4.2025"],
  
      aiName: ["Ai2sql"],
  
      aiWebsite: ["https://www.ai2sql.io/"],
  
      description: ["Enable non-engineers to write efficient SQL queries without knowing SQL."],
  
      imagePath: ["image-de2580317762a7dec6dd374082fcf540a2beb9e3-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCUYf9CHKyBmaYykn-YnJILw"] 
  
    ],
  
    { 
  
      id: ["8801c38a-c4dd-42ab-b06b-dae8dce2d58f"],
  
      date: ["6.4.2025"],
  
      aiName: ["Murf AI"],
  
      aiWebsite: ["https://get.murf.ai/14tctt7yqlir"],
  
      description: ["Create studio-quality voiceovers with AI-generate],real people's voices."],
  
      imagePath: ["image-d02772f185d575971672e190690ef8d0a2215ab4-1858x932-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCN4SZLCIuSKaLwQuDHR9evg"] 
  
    ],
  
    { 
  
      id: ["850ccfbe-f9d8-4285-a8ce-99ed937716dd"],
  
      date: ["7.4.2025"],
  
      aiName: ["Roboflow"],
  
      aiWebsite: ["https://roboflow.com/"],
  
      description: ["Train a computer vision model in an afternoon with images."],
  
      imagePath: ["image-6440e1f7c6674ddbaed320f2640038c621b05dab-1846x862-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCUlRrGpNRT5jbiV8h5Q_4Fg"] 
  
    ],
  
    { 
  
      id: ["79d51004-840e-4fcc-80c1-d3804735d36f"],
  
      date: ["9.4.2025"],
  
      aiName: ["DallE-2"],
  
      aiWebsite: ["https://openai.com/dall-e-2/"],
  
      description: ["Create realistic images from tex],combining concepts and styles."],
  
      imagePath: ["image-1cca013eba633e9c48234774a0d0cdc5ee7a6d34-1580x963-jpg"],
  
      videoIframeAdress: ["https://youtube.com/openai"] 
  
    ],
  
    { 
  
      id: ["76c8d0ce-d0b8-447f-ab08-eaaf87c8e886"],
  
      date: ["10.4.2025"],
  
      aiName: ["Runwayml"],
  
      aiWebsite: ["https://runwayml.com/"],
  
      description: ["Unlock advanced video editing to elevate your creations."],
  
      imagePath: ["image-31790ec63f8bb3f18c519f0a03c24042668f76b6-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/runwayml"] 
  
    ],
  
    { 
  
      id: ["2c2e2151-30a5-403f-98b9-0f06de16d79e"],
  
      date: ["23.4.2025"],
  
      aiName: ["Coqui"],
  
      aiWebsite: ["https://coqui.ai/"],
  
      description: ["Free speech platform for everyone"],
  
      imagePath: ["image-f1e21885729b2395f63a38be2c842b255a277b87-1680x876-png"],
  
      videoIframeAdress: ["https://www.youtube.com/@coqui1027"] 
  
    ],
  
    { 
  
      id: ["b8db03fb-48ce-4ee2-9d49-04fea76f3353"],
  
      date: ["4.5.2025"],
  
      aiName: ["ELI5"],
  
      aiWebsite: ["https://explainlikeimfive.io/"],
  
      description: ["Simplifies complex topics using AI for all levels of understanding"],
  
      imagePath: ["image-d17ebe5611a229038e220d39df884a085a5a1aaf-1574x932-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/@explainlikeimfive8385"] 
  
    ],
  
    { 
  
      id: ["8fd75a19-3f70-4fe3-ad22-cbaf8fce0604"],
  
      date: ["5.5.2025"],
  
      aiName: ["GetFloorPlan"],
  
      aiWebsite: ["https://getfloorplan.com/"],
  
      description: ["Convert 2D floor plan to 3D layout w/ 360 virtual tour & AI"],
  
      imagePath: ["image-c8d1e6a072443fbf8bb38e79de0e25bd8c19b226-1920x977-png"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCydg0Ebq6dpRt308_4G7b7w"] 
  
    ],
  
    { 
  
      id: ["ec847806-80eb-4cba-b88d-10b882785fb7"],
  
      date: ["15.5.2025"],
  
      aiName: ["Peech"],
  
      aiWebsite: ["https://www.peech-ai.com/"],
  
      description: ["Unlock video content creation"],
  
      imagePath: ["image-37516cb73a11ec2c8b1b8acdf3bde3d0feaeaf2e-1528x942-jpg"],
  
      videoIframeAdress: ["https://www.youtube.com/channel/UCPTjF_J04E_WK2gGHOdmcMw"] 
  
    } 
  
]
// Out:
// Expected ';', '}' or <eof> at repl.tsx:1:8
//
//   remove blank texts
//          ~~~~~:

// %%
texts
// Out:
// Stack trace:
// ReferenceError: texts is not defined
//     at <anonymous>:1:22
